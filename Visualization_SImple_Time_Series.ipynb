# %% [markdown]
# <a href="https://colab.research.google.com/github/diazonic/Machine-Learning-using-sklearn/blob/master/Visualization_SImple_Time_Series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df2 = pd.read_csv('/content/drive/My Drive/Diazonic Files/Python for Kids - DataScience/Archive 2/Archive/Plant_1_Weather_Sensor_Data.csv')
df2
# Out:
#                 DATE_TIME  PLANT_ID  ... MODULE_TEMPERATURE  IRRADIATION
# 0     2020-05-15 00:00:00   4135001  ...          22.857507          0.0
# 1     2020-05-15 00:15:00   4135001  ...          22.761668          0.0
# 2     2020-05-15 00:30:00   4135001  ...          22.592306          0.0
# 3     2020-05-15 00:45:00   4135001  ...          22.360852          0.0
# 4     2020-05-15 01:00:00   4135001  ...          22.165423          0.0
# ...                   ...       ...  ...                ...          ...
# 3177  2020-06-17 22:45:00   4135001  ...          21.480377          0.0
# 3178  2020-06-17 23:00:00   4135001  ...          21.389024          0.0
# 3179  2020-06-17 23:15:00   4135001  ...          20.709211          0.0
# 3180  2020-06-17 23:30:00   4135001  ...          20.734963          0.0
# 3181  2020-06-17 23:45:00   4135001  ...          20.427972          0.0
#
# [3182 rows x 6 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3182 entries, 0 to 3181
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DATE_TIME            3182 non-null   object
#  1   PLANT_ID             3182 non-null   int64
#  2   SOURCE_KEY           3182 non-null   object
#  3   AMBIENT_TEMPERATURE  3182 non-null   float64
#  4   MODULE_TEMPERATURE   3182 non-null   float64
#  5   IRRADIATION          3182 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 149.3+ KB

# %%
df2['DATE_TIME'] = pd.to_datetime(df2['DATE_TIME'],format = '%Y-%m-%d %H:%M')
df2['DATE_TIME']
# Out:
# 0      2020-05-15 00:00:00
# 1      2020-05-15 00:15:00
# 2      2020-05-15 00:30:00
# 3      2020-05-15 00:45:00
# 4      2020-05-15 01:00:00
#                ...
# 3177   2020-06-17 22:45:00
# 3178   2020-06-17 23:00:00
# 3179   2020-06-17 23:15:00
# 3180   2020-06-17 23:30:00
# 3181   2020-06-17 23:45:00
# Name: DATE_TIME, Length: 3182, dtype: datetime64[ns]

# %%
df2['DATE'] = pd.to_datetime(df2['DATE_TIME'],format = '%Y-%m-%d %H:%M:%S').dt.date
df2['DATE'] = pd.to_datetime(df2['DATE'])
df2['DATE']
# Out:
# 0      2020-05-15
# 1      2020-05-15
# 2      2020-05-15
# 3      2020-05-15
# 4      2020-05-15
#           ...
# 3177   2020-06-17
# 3178   2020-06-17
# 3179   2020-06-17
# 3180   2020-06-17
# 3181   2020-06-17
# Name: DATE, Length: 3182, dtype: datetime64[ns]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(18,9))
plt.plot(df2['DATE_TIME'],df2['AMBIENT_TEMPERATURE'],label = 'Ambient')
plt.legend()
plt.grid()
plt.margins(0.05)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(18,9))
plt.plot(df2['DATE_TIME'],df2['MODULE_TEMPERATURE'],label = 'Module')
plt.legend()
plt.grid()
plt.margins(0.05)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(18,9))
plt.plot(df2['DATE_TIME'],df2['MODULE_TEMPERATURE']-df2['AMBIENT_TEMPERATURE'],label='Difference')
plt.legend()
plt.grid()
plt.margins(0.05)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(18,9))
plt.plot(df2['DATE_TIME'],df2['AMBIENT_TEMPERATURE'],label = 'Ambient')
plt.plot(df2['DATE_TIME'],df2['MODULE_TEMPERATURE'],label = 'Module')
plt.plot(df2['DATE_TIME'],df2['MODULE_TEMPERATURE']-df2['AMBIENT_TEMPERATURE'],label='Difference')
# Combining different graphs give different colors [Blue,Orange,Green]
plt.legend()
plt.grid()
plt.margins(0.05)
plt.show()

# %%
plt.axis?

# %%
# Taking the mean value for smoothness of the graph
import matplotlib.pyplot as plt
plt.figure(figsize=(18,9))
plt.plot(df2['DATE_TIME'],df2['AMBIENT_TEMPERATURE'].rolling(window=20).mean(),label = 'Ambient')
plt.plot(df2['DATE_TIME'],df2['MODULE_TEMPERATURE'].rolling(window=20).mean(),label = 'Module')
plt.plot(df2['DATE_TIME'],(df2['MODULE_TEMPERATURE']-df2['AMBIENT_TEMPERATURE']).rolling(window=20).mean(),label='Difference')
# Combining different graphs give different colors [Blue,Orange,Green]
plt.legend()
plt.grid()
plt.margins(0.05)
plt.show()

# %%
# Taking scatter plot from plt.plot itself
import numpy as np
a = np.random.randint(1,1000,500)
b = np.random.randint(1,1000,500)
#plt.scatter(a,b) # Method 1
plt.plot(a,b,marker='o',linestyle='') #Method 2
plt.show()

# %%
# Plotting Ambient Temperature with Module Temperature

plt.figure(figsize=(18,9))
plt.plot(df2['AMBIENT_TEMPERATURE'],df2['MODULE_TEMPERATURE'],marker='o',
        linestyle='-', # Keep the linestyle empty,else you will get line
        alpha=.5,
        ms=10,
        label='Module Temperature (centigrade)')
plt.grid()
plt.margins(0.05)
plt.legend()
plt.title('Ambient Tempreture vs. Module Tempreture')
plt.xlabel('Ambient Tempreture')
plt.ylabel('Module Tempreture')
plt.show()

# %%
# Convert it into Datetime Object
df2['DATE'] = pd.to_datetime(df2['DATE_TIME'],format = '%Y-%m-%d %H:%M').dt.date

# %%
dates = df2['DATE'].unique()
dates
# Out:
# array([datetime.date(2020, 5, 15), datetime.date(2020, 5, 16),
#        datetime.date(2020, 5, 17), datetime.date(2020, 5, 18),
#        datetime.date(2020, 5, 19), datetime.date(2020, 5, 20),
#        datetime.date(2020, 5, 21), datetime.date(2020, 5, 22),
#        datetime.date(2020, 5, 23), datetime.date(2020, 5, 24),
#        datetime.date(2020, 5, 25), datetime.date(2020, 5, 26),
#        datetime.date(2020, 5, 27), datetime.date(2020, 5, 28),
#        datetime.date(2020, 5, 29), datetime.date(2020, 5, 30),
#        datetime.date(2020, 5, 31), datetime.date(2020, 6, 1),
#        datetime.date(2020, 6, 2), datetime.date(2020, 6, 3),
#        datetime.date(2020, 6, 4), datetime.date(2020, 6, 5),
#        datetime.date(2020, 6, 6), datetime.date(2020, 6, 7),
#        datetime.date(2020, 6, 8), datetime.date(2020, 6, 9),
#        datetime.date(2020, 6, 10), datetime.date(2020, 6, 11),
#        datetime.date(2020, 6, 12), datetime.date(2020, 6, 13),
#        datetime.date(2020, 6, 14), datetime.date(2020, 6, 15),
#        datetime.date(2020, 6, 16), datetime.date(2020, 6, 17)],
#       dtype=object)

# %%
dates[0]
# Out:
# datetime.date(2020, 5, 15)

# %%
df2
# Out:
#                DATE_TIME  PLANT_ID  ... IRRADIATION        DATE
# 0    2020-05-15 00:00:00   4135001  ...         0.0  2020-05-15
# 1    2020-05-15 00:15:00   4135001  ...         0.0  2020-05-15
# 2    2020-05-15 00:30:00   4135001  ...         0.0  2020-05-15
# 3    2020-05-15 00:45:00   4135001  ...         0.0  2020-05-15
# 4    2020-05-15 01:00:00   4135001  ...         0.0  2020-05-15
# ...                  ...       ...  ...         ...         ...
# 3177 2020-06-17 22:45:00   4135001  ...         0.0  2020-06-17
# 3178 2020-06-17 23:00:00   4135001  ...         0.0  2020-06-17
# 3179 2020-06-17 23:15:00   4135001  ...         0.0  2020-06-17
# 3180 2020-06-17 23:30:00   4135001  ...         0.0  2020-06-17
# 3181 2020-06-17 23:45:00   4135001  ...         0.0  2020-06-17
#
# [3182 rows x 7 columns]

# %% [markdown]
# # The values of irradiation which represents daytime values.
# Irradiation > 0 - Daytime (SUNLIGHT)
#
#
# Irradiation ==0 - Night Time ( NO SUNLIGHT)

# %%
# Plotting the Irradiation > 0 ( Sunlight value for one specific day)
# datetime.date(2020, 5, 15)
data = df2[df2['DATE']==dates[0]][df2['IRRADIATION']>0]
data
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
#              DATE_TIME  PLANT_ID  ... IRRADIATION        DATE
# 23 2020-05-15 05:45:00   4135001  ...    0.000863  2020-05-15
# 24 2020-05-15 06:00:00   4135001  ...    0.005887  2020-05-15
# 25 2020-05-15 06:15:00   4135001  ...    0.022282  2020-05-15
# 26 2020-05-15 06:30:00   4135001  ...    0.049410  2020-05-15
# 27 2020-05-15 06:45:00   4135001  ...    0.095394  2020-05-15
# 28 2020-05-15 07:00:00   4135001  ...    0.141940  2020-05-15
# 29 2020-05-15 07:15:00   4135001  ...    0.154713  2020-05-15
# 30 2020-05-15 07:30:00   4135001  ...    0.148799  2020-05-15
# 31 2020-05-15 07:45:00   4135001  ...    0.144793  2020-05-15
# 32 2020-05-15 08:00:00   4135001  ...    0.201639  2020-05-15
# 33 2020-05-15 08:15:00   4135001  ...    0.345708  2020-05-15
# 34 2020-05-15 08:30:00   4135001  ...    0.405349  2020-05-15
# 35 2020-05-15 08:45:00   4135001  ...    0.312427  2020-05-15
# 36 2020-05-15 09:00:00   4135001  ...    0.623153  2020-05-15
# 37 2020-05-15 09:15:00   4135001  ...    0.344884  2020-05-15
# 38 2020-05-15 09:30:00   4135001  ...    0.249248  2020-05-15
# 39 2020-05-15 09:45:00   4135001  ...    0.541206  2020-05-15
# 40 2020-05-15 10:00:00   4135001  ...    0.670675  2020-05-15
# 41 2020-05-15 10:15:00   4135001  ...    0.572283  2020-05-15
# 42 2020-05-15 10:30:00   4135001  ...    0.455148  2020-05-15
# 43 2020-05-15 10:45:00   4135001  ...    0.361962  2020-05-15
# 44 2020-05-15 11:00:00   4135001  ...    0.636561  2020-05-15
# 45 2020-05-15 11:15:00   4135001  ...    0.585787  2020-05-15
# 46 2020-05-15 11:30:00   4135001  ...    0.557069  2020-05-15
# 47 2020-05-15 11:45:00   4135001  ...    0.467987  2020-05-15
# 48 2020-05-15 12:00:00   4135001  ...    0.514963  2020-05-15
# 49 2020-05-15 12:15:00   4135001  ...    0.787866  2020-05-15
# 50 2020-05-15 12:30:00   4135001  ...    0.649248  2020-05-15
# 51 2020-05-15 12:45:00   4135001  ...    0.761243  2020-05-15
# 52 2020-05-15 13:00:00   4135001  ...    0.416035  2020-05-15
# 53 2020-05-15 13:15:00   4135001  ...    0.489244  2020-05-15
# 54 2020-05-15 13:30:00   4135001  ...    0.574561  2020-05-15
# 55 2020-05-15 13:45:00   4135001  ...    0.560986  2020-05-15
# 56 2020-05-15 14:00:00   4135001  ...    0.735083  2020-05-15
# 57 2020-05-15 14:15:00   4135001  ...    0.893661  2020-05-15
# 58 2020-05-15 14:30:00   4135001  ...    0.466789  2020-05-15
# 59 2020-05-15 14:45:00   4135001  ...    0.542138  2020-05-15
# 60 2020-05-15 15:00:00   4135001  ...    0.398889  2020-05-15
# 61 2020-05-15 15:15:00   4135001  ...    0.447292  2020-05-15
# 62 2020-05-15 15:30:00   4135001  ...    0.565196  2020-05-15
# 63 2020-05-15 15:45:00   4135001  ...    0.346231  2020-05-15
# 64 2020-05-15 16:00:00   4135001  ...    0.358182  2020-05-15
# 65 2020-05-15 16:15:00   4135001  ...    0.328896  2020-05-15
# 66 2020-05-15 16:30:00   4135001  ...    0.344954  2020-05-15
# 67 2020-05-15 16:45:00   4135001  ...    0.260347  2020-05-15
# 68 2020-05-15 17:00:00   4135001  ...    0.166813  2020-05-15
# 69 2020-05-15 17:15:00   4135001  ...    0.173899  2020-05-15
# 70 2020-05-15 17:30:00   4135001  ...    0.087162  2020-05-15
# 71 2020-05-15 17:45:00   4135001  ...    0.038403  2020-05-15
# 72 2020-05-15 18:00:00   4135001  ...    0.022545  2020-05-15
# 73 2020-05-15 18:15:00   4135001  ...    0.009150  2020-05-15
# 74 2020-05-15 18:30:00   4135001  ...    0.001841  2020-05-15
# 78 2020-05-15 19:30:00   4135001  ...    0.000125  2020-05-15
# 79 2020-05-15 19:45:00   4135001  ...    0.000100  2020-05-15
#
# [54 rows x 7 columns]

# %%
# One specific Date Plot
plt.figure(figsize=(18,9))
data = df2[df2['DATE']==dates[0]][df2['IRRADIATION']>0]
plt.plot(data['AMBIENT_TEMPERATURE'],
            data['MODULE_TEMPERATURE'],
            marker='o',
            linestyle='',
            alpha=.5,
            ms=10,
            label=pd.to_datetime(date,format='%Y-%m-%d').date()
           )
plt.grid()
plt.margins(0.05)
plt.legend()
plt.title('Module Tempreture vs. Ambient Tempreture')
plt.xlabel('Ambient Tempreture')
plt.ylabel('Module Tempreture')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-38aa43d72a7c> in <module>()
#       8             alpha=.5,
#       9             ms=10,
# ---> 10             label=pd.to_datetime(date,format='%Y-%m-%d').date()
#      11            )
#      12 plt.grid()
#
# NameError: name 'date' is not defined

# %%
# Plotting the above for all dates
plt.figure(figsize=(18,9))
for date in dates:
    data = df2[df2['DATE']==date][df2['IRRADIATION']>0]

    plt.plot(data['AMBIENT_TEMPERATURE'],
            data['MODULE_TEMPERATURE'],
            marker='o',
            linestyle='',
            alpha=.5,
            ms=10,
            label=pd.to_datetime(date,format='%Y-%m-%d').date()
           )
plt.grid()
plt.margins(0.05)
plt.legend()
plt.title('Module Tempreture vs. Ambient Tempreture')
plt.xlabel('Ambient Tempreture')
plt.ylabel('Module Tempreture')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.

# %%
plt.plot(df2['IRRADIATION'],
        df2['MODULE_TEMPERATURE'],
        marker='o',
        linestyle='',
        alpha=.5,
        ms=10,
        label='module temperature')

# %%
data = df2[df2['IRRADIATION']>0.1]
plt.plot(data['IRRADIATION'],
        data['MODULE_TEMPERATURE']-data['AMBIENT_TEMPERATURE'],
        marker='o',
        linestyle='',
        alpha=.5,
        ms=10,
        label='temperature difference')

# %%
df1 = pd.read_csv('/content/drive/My Drive/Diazonic Files/Python for Kids - DataScience/Archive 2/Archive/Plant_1_Generation_Data.csv')
df1['DATE_TIME'] = pd.to_datetime(df1['DATE_TIME'],format ='%d-%m-%Y %H:%M')
# Convert it into Datetime Object
df1['DATE'] = pd.to_datetime(df1['DATE_TIME'],format = '%d-%m-%Y %H:%M').dt.date
df1['DATE'] = pd.to_datetime(df1['DATE'])
df1
# Out:
#                 DATE_TIME  PLANT_ID  ... TOTAL_YIELD       DATE
# 0     2020-05-15 00:00:00   4135001  ...   6259559.0 2020-05-15
# 1     2020-05-15 00:00:00   4135001  ...   6183645.0 2020-05-15
# 2     2020-05-15 00:00:00   4135001  ...   6987759.0 2020-05-15
# 3     2020-05-15 00:00:00   4135001  ...   7602960.0 2020-05-15
# 4     2020-05-15 00:00:00   4135001  ...   7158964.0 2020-05-15
# ...                   ...       ...  ...         ...        ...
# 68773 2020-06-17 23:45:00   4135001  ...   7287002.0 2020-06-17
# 68774 2020-06-17 23:45:00   4135001  ...   7028601.0 2020-06-17
# 68775 2020-06-17 23:45:00   4135001  ...   7251204.0 2020-06-17
# 68776 2020-06-17 23:45:00   4135001  ...   6583369.0 2020-06-17
# 68777 2020-06-17 23:45:00   4135001  ...   7363272.0 2020-06-17
#
# [68778 rows x 8 columns]

# %%
inv_lst = df1['SOURCE_KEY'].unique()
inv_lst
# Out:
# array(['1BY6WEcLGh8j5v7', '1IF53ai7Xc0U56Y', '3PZuoBAID5Wc2HD',
#        '7JYdWkrLSPkdwr4', 'McdE0feGgRqW7Ca', 'VHMLBKoKgIrUVDU',
#        'WRmjgnKYAwPKWDb', 'ZnxXDlPa8U1GXgE', 'ZoEaEvLYb1n2sOq',
#        'adLQvlD726eNBSB', 'bvBOhCH3iADSZry', 'iCRJl6heRkivqQ3',
#        'ih0vzX44oOqAx2f', 'pkci93gMrogZuBj', 'rGa61gmuvPhdLxV',
#        'sjndEbLyjtCKgGv', 'uHbuxQJl8lW7ozc', 'wCURE6d3bPkepu2',
#        'z9Y9gH1T5YWrNuG', 'zBIq5rxdHJRwDNY', 'zVJPv84UY57bAof',
#        'YxYtjZvoooNbGkE'], dtype=object)

# %%
plt.bar(inv_lst,df1.groupby('SOURCE_KEY')['TOTAL_YIELD'].max())
plt.xticks(rotation=90)
plt.grid()

# %%
# MERGING 2 DATASETS

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68778 entries, 0 to 68777
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATE_TIME    68778 non-null  datetime64[ns]
#  1   PLANT_ID     68778 non-null  int64
#  2   SOURCE_KEY   68778 non-null  object
#  3   DC_POWER     68778 non-null  float64
#  4   AC_POWER     68778 non-null  float64
#  5   DAILY_YIELD  68778 non-null  float64
#  6   TOTAL_YIELD  68778 non-null  float64
#  7   DATE         68778 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(4), int64(1), object(1)
# memory usage: 4.2+ MB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3182 entries, 0 to 3181
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DATE_TIME            3182 non-null   datetime64[ns]
#  1   PLANT_ID             3182 non-null   int64
#  2   SOURCE_KEY           3182 non-null   object
#  3   AMBIENT_TEMPERATURE  3182 non-null   float64
#  4   MODULE_TEMPERATURE   3182 non-null   float64
#  5   IRRADIATION          3182 non-null   float64
#  6   DATE                 3182 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(3), int64(1), object(1)
# memory usage: 174.1+ KB

# %%
r_left = pd.merge(df1,df2, on='DATE_TIME',how='left')
r_left
# Out:
#                 DATE_TIME  PLANT_ID_x  ... IRRADIATION     DATE_y
# 0     2020-05-15 00:00:00     4135001  ...         0.0 2020-05-15
# 1     2020-05-15 00:00:00     4135001  ...         0.0 2020-05-15
# 2     2020-05-15 00:00:00     4135001  ...         0.0 2020-05-15
# 3     2020-05-15 00:00:00     4135001  ...         0.0 2020-05-15
# 4     2020-05-15 00:00:00     4135001  ...         0.0 2020-05-15
# ...                   ...         ...  ...         ...        ...
# 68773 2020-06-17 23:45:00     4135001  ...         0.0 2020-06-17
# 68774 2020-06-17 23:45:00     4135001  ...         0.0 2020-06-17
# 68775 2020-06-17 23:45:00     4135001  ...         0.0 2020-06-17
# 68776 2020-06-17 23:45:00     4135001  ...         0.0 2020-06-17
# 68777 2020-06-17 23:45:00     4135001  ...         0.0 2020-06-17
#
# [68778 rows x 14 columns]

# %%
r_left.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 68778 entries, 0 to 68777
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DATE_TIME            68778 non-null  datetime64[ns]
#  1   PLANT_ID_x           68778 non-null  int64
#  2   SOURCE_KEY_x         68778 non-null  object
#  3   DC_POWER             68778 non-null  float64
#  4   AC_POWER             68778 non-null  float64
#  5   DAILY_YIELD          68778 non-null  float64
#  6   TOTAL_YIELD          68778 non-null  float64
#  7   DATE_x               68778 non-null  datetime64[ns]
#  8   PLANT_ID_y           68774 non-null  float64
#  9   SOURCE_KEY_y         68774 non-null  object
#  10  AMBIENT_TEMPERATURE  68774 non-null  float64
#  11  MODULE_TEMPERATURE   68774 non-null  float64
#  12  IRRADIATION          68774 non-null  float64
#  13  DATE_y               68774 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), float64(8), int64(1), object(2)
# memory usage: 7.9+ MB

# %%
r_left['AMBIENT_TEMPERATURE'].isnull().value_counts()
# Out:
# False    68774
# True         4
# Name: AMBIENT_TEMPERATURE, dtype: int64

# %%
null_data = r_left[r_left.isnull().any(axis=1)]

# %%
null_data
# Sensor value was down at this time stamp
# Out:
#                 DATE_TIME  PLANT_ID_x  ... IRRADIATION  DATE_y
# 38544 2020-06-03 14:00:00     4135001  ...         NaN     NaT
# 38545 2020-06-03 14:00:00     4135001  ...         NaN     NaT
# 38546 2020-06-03 14:00:00     4135001  ...         NaN     NaT
# 38547 2020-06-03 14:00:00     4135001  ...         NaN     NaT
#
# [4 rows x 14 columns]

# %%
r_left[r_left['DATE_TIME']=='2020-06-03 14:00:00']
# Out:
#                 DATE_TIME  PLANT_ID_x  ... IRRADIATION  DATE_y
# 38544 2020-06-03 14:00:00     4135001  ...         NaN     NaT
# 38545 2020-06-03 14:00:00     4135001  ...         NaN     NaT
# 38546 2020-06-03 14:00:00     4135001  ...         NaN     NaT
# 38547 2020-06-03 14:00:00     4135001  ...         NaN     NaT
#
# [4 rows x 14 columns]

# %%
r_right = pd.merge(df1,df2, on='DATE_TIME',how='right')
r_right
# Out:
#                 DATE_TIME  PLANT_ID_x  ... IRRADIATION     DATE_y
# 0     2020-05-15 00:00:00   4135001.0  ...    0.000000 2020-05-15
# 1     2020-05-15 00:00:00   4135001.0  ...    0.000000 2020-05-15
# 2     2020-05-15 00:00:00   4135001.0  ...    0.000000 2020-05-15
# 3     2020-05-15 00:00:00   4135001.0  ...    0.000000 2020-05-15
# 4     2020-05-15 00:00:00   4135001.0  ...    0.000000 2020-05-15
# ...                   ...         ...  ...         ...        ...
# 68794 2020-05-29 01:15:00         NaN  ...    0.000000 2020-05-29
# 68795 2020-05-29 01:30:00         NaN  ...    0.000000 2020-05-29
# 68796 2020-05-29 01:45:00         NaN  ...    0.000000 2020-05-29
# 68797 2020-06-17 06:15:00         NaN  ...    0.019175 2020-06-17
# 68798 2020-06-17 06:30:00         NaN  ...    0.034624 2020-06-17
#
# [68799 rows x 14 columns]

# %%
r_right.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 68799 entries, 0 to 68798
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DATE_TIME            68799 non-null  datetime64[ns]
#  1   PLANT_ID_x           68774 non-null  float64
#  2   SOURCE_KEY_x         68774 non-null  object
#  3   DC_POWER             68774 non-null  float64
#  4   AC_POWER             68774 non-null  float64
#  5   DAILY_YIELD          68774 non-null  float64
#  6   TOTAL_YIELD          68774 non-null  float64
#  7   DATE_x               68774 non-null  datetime64[ns]
#  8   PLANT_ID_y           68799 non-null  int64
#  9   SOURCE_KEY_y         68799 non-null  object
#  10  AMBIENT_TEMPERATURE  68799 non-null  float64
#  11  MODULE_TEMPERATURE   68799 non-null  float64
#  12  IRRADIATION          68799 non-null  float64
#  13  DATE_y               68799 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), float64(8), int64(1), object(2)
# memory usage: 7.9+ MB

# %%
r_right['DC_POWER'].isnull().value_counts()
# Out:
# False    68774
# True        25
# Name: DC_POWER, dtype: int64

# %%
null_data2 = r_right[r_right.isnull().any(axis=1)]
null_data2
# Out:
#                 DATE_TIME  PLANT_ID_x  ... IRRADIATION     DATE_y
# 68774 2020-05-20 23:00:00         NaN  ...    0.000000 2020-05-20
# 68775 2020-05-20 23:15:00         NaN  ...    0.000000 2020-05-20
# 68776 2020-05-20 23:30:00         NaN  ...    0.000000 2020-05-20
# 68777 2020-05-20 23:45:00         NaN  ...    0.000000 2020-05-20
# 68778 2020-05-21 00:00:00         NaN  ...    0.000000 2020-05-21
# 68779 2020-05-21 00:15:00         NaN  ...    0.000000 2020-05-21
# 68780 2020-05-21 00:30:00         NaN  ...    0.000000 2020-05-21
# 68781 2020-05-23 05:15:00         NaN  ...    0.000000 2020-05-23
# 68782 2020-05-25 05:45:00         NaN  ...    0.001908 2020-05-25
# 68783 2020-05-28 22:30:00         NaN  ...    0.000000 2020-05-28
# 68784 2020-05-28 22:45:00         NaN  ...    0.000000 2020-05-28
# 68785 2020-05-28 23:00:00         NaN  ...    0.000000 2020-05-28
# 68786 2020-05-28 23:15:00         NaN  ...    0.000000 2020-05-28
# 68787 2020-05-28 23:30:00         NaN  ...    0.000000 2020-05-28
# 68788 2020-05-28 23:45:00         NaN  ...    0.000000 2020-05-28
# 68789 2020-05-29 00:00:00         NaN  ...    0.000000 2020-05-29
# 68790 2020-05-29 00:15:00         NaN  ...    0.000000 2020-05-29
# 68791 2020-05-29 00:30:00         NaN  ...    0.000000 2020-05-29
# 68792 2020-05-29 00:45:00         NaN  ...    0.000000 2020-05-29
# 68793 2020-05-29 01:00:00         NaN  ...    0.000000 2020-05-29
# 68794 2020-05-29 01:15:00         NaN  ...    0.000000 2020-05-29
# 68795 2020-05-29 01:30:00         NaN  ...    0.000000 2020-05-29
# 68796 2020-05-29 01:45:00         NaN  ...    0.000000 2020-05-29
# 68797 2020-06-17 06:15:00         NaN  ...    0.019175 2020-06-17
# 68798 2020-06-17 06:30:00         NaN  ...    0.034624 2020-06-17
#
# [25 rows x 14 columns]

# %%
null_data2.nunique()
# Out:
# DATE_TIME              25
# PLANT_ID_x              0
# SOURCE_KEY_x            0
# DC_POWER                0
# AC_POWER                0
# DAILY_YIELD             0
# TOTAL_YIELD             0
# DATE_x                  0
# PLANT_ID_y              1
# SOURCE_KEY_y            1
# AMBIENT_TEMPERATURE    25
# MODULE_TEMPERATURE     25
# IRRADIATION             4
# DATE_y                  7
# dtype: int64

# %%
null_data2['DATE_TIME'].unique()
# Out:
# array(['2020-05-20T23:00:00.000000000', '2020-05-20T23:15:00.000000000',
#        '2020-05-20T23:30:00.000000000', '2020-05-20T23:45:00.000000000',
#        '2020-05-21T00:00:00.000000000', '2020-05-21T00:15:00.000000000',
#        '2020-05-21T00:30:00.000000000', '2020-05-23T05:15:00.000000000',
#        '2020-05-25T05:45:00.000000000', '2020-05-28T22:30:00.000000000',
#        '2020-05-28T22:45:00.000000000', '2020-05-28T23:00:00.000000000',
#        '2020-05-28T23:15:00.000000000', '2020-05-28T23:30:00.000000000',
#        '2020-05-28T23:45:00.000000000', '2020-05-29T00:00:00.000000000',
#        '2020-05-29T00:15:00.000000000', '2020-05-29T00:30:00.000000000',
#        '2020-05-29T00:45:00.000000000', '2020-05-29T01:00:00.000000000',
#        '2020-05-29T01:15:00.000000000', '2020-05-29T01:30:00.000000000',
#        '2020-05-29T01:45:00.000000000', '2020-06-17T06:15:00.000000000',
#        '2020-06-17T06:30:00.000000000'], dtype='datetime64[ns]')

# %%
plt.figure(figsize=(18,9))
plt.plot(r_left['IRRADIATION'],r_left['DC_POWER'],marker='o',linestyle='',label='DC POWER',alpha=0.5)

# %%
plt.figure(figsize=(18,9))
plt.plot(r_left['MODULE_TEMPERATURE'],r_left['DC_POWER'],marker='o',linestyle='',label='DC POWER',alpha=0.5)

# %%
dates = r_left['DATE_x'].unique()
dates
# Out:
# array(['2020-05-15T00:00:00.000000000', '2020-05-16T00:00:00.000000000',
#        '2020-05-17T00:00:00.000000000', '2020-05-18T00:00:00.000000000',
#        '2020-05-19T00:00:00.000000000', '2020-05-20T00:00:00.000000000',
#        '2020-05-21T00:00:00.000000000', '2020-05-22T00:00:00.000000000',
#        '2020-05-23T00:00:00.000000000', '2020-05-24T00:00:00.000000000',
#        '2020-05-25T00:00:00.000000000', '2020-05-26T00:00:00.000000000',
#        '2020-05-27T00:00:00.000000000', '2020-05-28T00:00:00.000000000',
#        '2020-05-29T00:00:00.000000000', '2020-05-30T00:00:00.000000000',
#        '2020-05-31T00:00:00.000000000', '2020-06-01T00:00:00.000000000',
#        '2020-06-02T00:00:00.000000000', '2020-06-03T00:00:00.000000000',
#        '2020-06-04T00:00:00.000000000', '2020-06-05T00:00:00.000000000',
#        '2020-06-06T00:00:00.000000000', '2020-06-07T00:00:00.000000000',
#        '2020-06-08T00:00:00.000000000', '2020-06-09T00:00:00.000000000',
#        '2020-06-10T00:00:00.000000000', '2020-06-11T00:00:00.000000000',
#        '2020-06-12T00:00:00.000000000', '2020-06-13T00:00:00.000000000',
#        '2020-06-14T00:00:00.000000000', '2020-06-15T00:00:00.000000000',
#        '2020-06-16T00:00:00.000000000', '2020-06-17T00:00:00.000000000'],
#       dtype='datetime64[ns]')

# %%
plt.figure(figsize=(18,9))
for date in dates:
  data = r_left[r_left['DATE_x']==date][r_left['IRRADIATION']>0.1]
  plt.plot(data['MODULE_TEMPERATURE'],data['DC_POWER'],marker='o',linestyle='',label=pd.to_datetime(date,format='%Y-%m-%d').date())
plt.legend()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.figure(figsize=(18,9))
date = dates[4]
inverters =r_left['SOURCE_KEY_x'].unique()
for inverter in inverters:
  data = r_left[r_left['DATE_x']==date][r_left['SOURCE_KEY_x']==inverter]
  plt.plot(data['MODULE_TEMPERATURE'],data['DC_POWER'],marker='o',linestyle='',label=inverter)
plt.legend()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """

# %%
data_summary = df1.groupby(['SOURCE_KEY','DATE']).agg(READINGS = ('TOTAL_YIELD','count'),
                                                  INV = ('SOURCE_KEY', max),
                                                  DATE = ('DATE',max))

# %%
data_summary
# Out:
#                             READINGS              INV       DATE
# SOURCE_KEY      DATE
# 1BY6WEcLGh8j5v7 2020-05-15        93  1BY6WEcLGh8j5v7 2020-05-15
#                 2020-05-16        88  1BY6WEcLGh8j5v7 2020-05-16
#                 2020-05-17        96  1BY6WEcLGh8j5v7 2020-05-17
#                 2020-05-18        96  1BY6WEcLGh8j5v7 2020-05-18
#                 2020-05-19        93  1BY6WEcLGh8j5v7 2020-05-19
# ...                              ...              ...        ...
# zVJPv84UY57bAof 2020-06-13        96  zVJPv84UY57bAof 2020-06-13
#                 2020-06-14        96  zVJPv84UY57bAof 2020-06-14
#                 2020-06-15        96  zVJPv84UY57bAof 2020-06-15
#                 2020-06-16        96  zVJPv84UY57bAof 2020-06-16
#                 2020-06-17        94  zVJPv84UY57bAof 2020-06-17
#
# [748 rows x 3 columns]

# %%
data_summary.head()
# Out:
#                             READINGS              INV       DATE
# SOURCE_KEY      DATE
# 1BY6WEcLGh8j5v7 2020-05-15        93  1BY6WEcLGh8j5v7 2020-05-15
#                 2020-05-16        88  1BY6WEcLGh8j5v7 2020-05-16
#                 2020-05-17        96  1BY6WEcLGh8j5v7 2020-05-17
#                 2020-05-18        96  1BY6WEcLGh8j5v7 2020-05-18
#                 2020-05-19        93  1BY6WEcLGh8j5v7 2020-05-19

# %%
plt.figure(figsize=(18,9))
for inv in data_summary['INV'].unique():

    plt.plot(data_summary[data_summary['INV']==inv]['DATE'],
            data_summary[data_summary['INV']==inv]['READINGS'],
            marker='o',
            linestyle='',
            alpha=.5,
            ms=10,
            label=inv)

plt.legend()
plt.title('Readings vs. Date')
plt.xlabel('Date')
plt.ylabel('Number of Readings')
plt.show()
